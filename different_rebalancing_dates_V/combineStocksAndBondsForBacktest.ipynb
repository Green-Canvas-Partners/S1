# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import numpy as np

import sys
import os
# Current working directory in Jupyter Notebook
project_root = os.getcwd()  # Current working directory
project_root = os.path.join(project_root, '..')  # Move one level up to the root
sys.path.append(project_root)
# from importlib import reload
# import utils.custom
# reload(utils.custom)
from utils.custom import calculate_metrics, plot_returns
from definitions.constants_V import DIFF_REBALANCING_STOCK_DICT_ALL_PKL_V, DIFF_REBALANCING_RETURNS_ALL_PKL_V, DATE_GS_CUTOFF #DIFF_REBALANCING_COMBINED_DATA_CSV


# dfsfilename=DIFF_REBALANCING_COMBINED_DATA_ALL_CSV
# dfsfilename=dfsfilename
# picasodfs=pd.read_pickle(dfsfilename)

stock_dict_filename=DIFF_REBALANCING_STOCK_DICT_ALL_PKL_V
stock_dict_filename=stock_dict_filename
stks=pd.read_pickle(stock_dict_filename)

rets_filename=DIFF_REBALANCING_RETURNS_ALL_PKL_V
rets_filename=rets_filename
retss=pd.read_pickle(rets_filename)

# %%
# picasodfs[0]

# %%
retss[1]
# Out:
#               returns
# t
# 2006-01-30   0.000000
# 2006-02-27   0.000000
# 2006-03-30   0.000000
# 2006-04-27   0.000000
# 2006-05-30   0.000000
# ...               ...
# 2023-03-30   0.000000
# 2023-04-27   0.000000
# 2023-05-30   3.198740
# 2023-06-29  10.773215
# 2023-07-28  -4.284189
#
# [211 rows x 1 columns]

# %%
stks[1]
# Out:
# {'2006-01-30': array([], dtype=float64),
#  '2006-02-27': array([], dtype=float64),
#  '2006-03-30': array([], dtype=float64),
#  '2006-04-27': array([], dtype=float64),
#  '2006-05-30': array([], dtype=float64),
#  '2006-06-29': array([], dtype=float64),
#  '2006-07-28': array([], dtype=float64),
#  '2006-08-30': array([], dtype=float64),
#  '2006-09-28': array([], dtype=float64),
#  '2006-10-30': array([], dtype=float64),
#  '2006-11-29': array([], dtype=float64),
#  '2006-12-28': array([], dtype=float64),
#  '2007-01-30': array([], dtype=float64),
#  '2007-02-27': array([], dtype=float64),
#  '2007-03-29': array([], dtype=float64),
#  '2007-04-27': array([], dtype=float64),
#  '2007-05-30': array([], dtype=float64),
#  '2007-06-28': array([], dtype=float64),
#  '2007-07-30': array([], dtype=float64),
#  '2007-08-30': array([], dtype=float64),
#  '2007-09-27': array([], dtype=float64),
#  '2007-10-30': array([], dtype=float64),
#  '2007-11-29': array([], dtype=float64),
#  '2007-12-28': array([], dtype=float64),
#  '2008-01-30': array([], dtype=float64),
#  '2008-02-28': array([], dtype=float64),
#  '2008-03-28': array([], dtype=float64),
#  '2008-04-29': array([], dtype=float64),
#  '2008-05-29': array([], dtype=float64),
#  '2008-06-27': array([], dtype=float64),
#  '2008-07-30': array([], dtype=float64),
#  '2008-08-28': array([], dtype=float64),
#  '2008-09-29': array([], dtype=float64),
#  '2008-10-30': array([], dtype=float64),
#  '2008-11-26': array(['GS', 'GOOG', 'MSFT'], dtype=object),
#  '2008-12-30': array(['GS', 'GOOG', 'MSFT'], dtype=object),
#  '2009-01-29': array(['GOOG', 'EEM', 'BAC'], dtype=object),
#  '2009-02-26': array(['BAC', 'EEM', 'XLF'], dtype=object),
#  '2009-03-30': array(['BAC', 'GE', 'XLF'], dtype=object),
#  '2009-04-29': array(['BAC', 'XLF', 'GE'], dtype=object),
#  '2009-05-28': array(['BAC', 'XLF', 'MSFT'], dtype=object),
#  '2009-06-29': array(['BAC', 'XLF', 'MSFT'], dtype=object),
#  '2009-07-30': array([], dtype=float64),
#  '2009-08-28': array([], dtype=float64),
#  '2009-09-29': array([], dtype=float64),
#  '2009-10-29': array([], dtype=float64),
#  '2009-11-27': array([], dtype=float64),
#  '2009-12-30': array([], dtype=float64),
#  '2010-01-28': array([], dtype=float64),
#  '2010-02-25': array([], dtype=float64),
#  '2010-03-30': array([], dtype=float64),
#  '2010-04-29': array([], dtype=float64),
#  '2010-05-27': array([], dtype=float64),
#  '2010-06-29': array([], dtype=float64),
#  '2010-07-29': array([], dtype=float64),
#  '2010-08-30': array(['XOM', 'JPM', 'EEM'], dtype=object),
#  '2010-09-29': array(['GS', 'MSFT', 'JPM'], dtype=object),
#  '2010-10-28': array(['GOOG', 'GS', 'AAPL'], dtype=object),
#  '2010-11-29': array(['GOOG', 'WFC', 'JPM'], dtype=object),
#  '2010-12-30': array(['GOOG', 'WFC', 'JPM'], dtype=object),
#  '2011-01-28': array([], dtype=float64),
#  '2011-02-25': array([], dtype=float64),
#  '2011-03-30': array([], dtype=float64),
#  '2011-04-28': array([], dtype=float64),
#  '2011-05-27': array([], dtype=float64),
#  '2011-06-29': array([], dtype=float64),
#  '2011-07-28': array([], dtype=float64),
#  '2011-08-30': array([], dtype=float64),
#  '2011-09-29': array([], dtype=float64),
#  '2011-10-28': array([], dtype=float64),
#  '2011-11-29': array([], dtype=float64),
#  '2011-12-29': array(['JPM', 'BAC', 'IWM'], dtype=object),
#  '2012-01-30': array(['MSFT', 'BAC', 'AAPL'], dtype=object),
#  '2012-02-28': array(['MSFT', 'BAC', 'AAPL'], dtype=object),
#  '2012-03-29': array(['BAC', 'JPM', 'MSFT'], dtype=object),
#  '2012-04-27': array([], dtype=float64),
#  '2012-05-30': array([], dtype=float64),
#  '2012-06-28': array([], dtype=float64),
#  '2012-07-30': array(['C', 'BAC', 'AAPL'], dtype=object),
#  '2012-08-30': array(['C', 'BAC', 'EEM'], dtype=object),
#  '2012-09-27': array(['BAC', 'C', 'JPM'], dtype=object),
#  '2012-10-26': array([], dtype=float64),
#  '2012-11-29': array([], dtype=float64),
#  '2012-12-28': array([], dtype=float64),
#  '2013-01-30': array([], dtype=float64),
#  '2013-02-27': array([], dtype=float64),
#  '2013-03-27': array([], dtype=float64),
#  '2013-04-29': array([], dtype=float64),
#  '2013-05-30': array([], dtype=float64),
#  '2013-06-27': array([], dtype=float64),
#  '2013-07-30': array([], dtype=float64),
#  '2013-08-29': array([], dtype=float64),
#  '2013-09-27': array([], dtype=float64),
#  '2013-10-30': array([], dtype=float64),
#  '2013-11-27': array([], dtype=float64),
#  '2013-12-30': array([], dtype=float64),
#  '2014-01-30': array([], dtype=float64),
#  '2014-02-27': array([], dtype=float64),
#  '2014-03-28': array([], dtype=float64),
#  '2014-04-29': array([], dtype=float64),
#  '2014-05-29': array([], dtype=float64),
#  '2014-06-27': array([], dtype=float64),
#  '2014-07-30': array([], dtype=float64),
#  '2014-08-28': array([], dtype=float64),
#  '2014-09-29': array([], dtype=float64),
#  '2014-10-30': array([], dtype=float64),
#  '2014-11-26': array([], dtype=float64),
#  '2014-12-30': array([], dtype=float64),
#  '2015-01-29': array([], dtype=float64),
#  '2015-02-26': array([], dtype=float64),
#  '2015-03-30': array([], dtype=float64),
#  '2015-04-29': array([], dtype=float64),
#  '2015-05-28': array([], dtype=float64),
#  '2015-06-29': array([], dtype=float64),
#  '2015-07-30': array([], dtype=float64),
#  '2015-08-28': array([], dtype=float64),
#  '2015-09-29': array([], dtype=float64),
#  '2015-10-29': array([], dtype=float64),
#  '2015-11-27': array([], dtype=float64),
#  '2015-12-30': array([], dtype=float64),
#  '2016-01-28': array([], dtype=float64),
#  '2016-02-26': array([], dtype=float64),
#  '2016-03-30': array([], dtype=float64),
#  '2016-04-28': array([], dtype=float64),
#  '2016-05-27': array([], dtype=float64),
#  '2016-06-29': array([], dtype=float64),
#  '2016-07-28': array([], dtype=float64),
#  '2016-08-30': array([], dtype=float64),
#  '2016-09-29': array([], dtype=float64),
#  '2016-10-28': array([], dtype=float64),
#  '2016-11-29': array([], dtype=float64),
#  '2016-12-29': array([], dtype=float64),
#  '2017-01-30': array([], dtype=float64),
#  '2017-02-27': array([], dtype=float64),
#  '2017-03-30': array([], dtype=float64),
#  '2017-04-27': array(['AAPL', 'FB', 'MSFT'], dtype=object),
#  '2017-05-30': array([], dtype=float64),
#  '2017-06-29': array([], dtype=float64),
#  '2017-07-28': array([], dtype=float64),
#  '2017-08-30': array([], dtype=float64),
#  '2017-09-28': array([], dtype=float64),
#  '2017-10-30': array([], dtype=float64),
#  '2017-11-29': array(['AMZN', 'MSFT', 'BAC'], dtype=object),
#  '2017-12-28': array(['AMZN', 'BAC', 'GDX'], dtype=object),
#  '2018-01-30': array([], dtype=float64),
#  '2018-02-27': array([], dtype=float64),
#  '2018-03-28': array([], dtype=float64),
#  '2018-04-27': array([], dtype=float64),
#  '2018-05-30': array([], dtype=float64),
#  '2018-06-28': array([], dtype=float64),
#  '2018-07-30': array([], dtype=float64),
#  '2018-08-30': array([], dtype=float64),
#  '2018-09-27': array([], dtype=float64),
#  '2018-10-30': array([], dtype=float64),
#  '2018-11-29': array([], dtype=float64),
#  '2018-12-28': array([], dtype=float64),
#  '2019-01-30': array([], dtype=float64),
#  '2019-02-27': array([], dtype=float64),
#  '2019-03-28': array([], dtype=float64),
#  '2019-04-29': array([], dtype=float64),
#  '2019-05-30': array([], dtype=float64),
#  '2019-06-27': array([], dtype=float64),
#  '2019-07-30': array([], dtype=float64),
#  '2019-08-29': array([], dtype=float64),
#  '2019-09-27': array([], dtype=float64),
#  '2019-10-30': array([], dtype=float64),
#  '2019-11-27': array([], dtype=float64),
#  '2019-12-30': array([], dtype=float64),
#  '2020-01-30': array([], dtype=float64),
#  '2020-02-27': array([], dtype=float64),
#  '2020-03-30': array([], dtype=float64),
#  '2020-04-29': array([], dtype=float64),
#  '2020-05-28': array([], dtype=float64),
#  '2020-06-29': array([], dtype=float64),
#  '2020-07-30': array([], dtype=float64),
#  '2020-08-28': array([], dtype=float64),
#  '2020-09-29': array([], dtype=float64),
#  '2020-10-29': array([], dtype=float64),
#  '2020-11-27': array([], dtype=float64),
#  '2020-12-30': array([], dtype=float64),
#  '2021-01-28': array([], dtype=float64),
#  '2021-02-25': array([], dtype=float64),
#  '2021-03-30': array([], dtype=float64),
#  '2021-04-29': array([], dtype=float64),
#  '2021-05-27': array([], dtype=float64),
#  '2021-06-29': array([], dtype=float64),
#  '2021-07-29': array([], dtype=float64),
#  '2021-08-30': array([], dtype=float64),
#  '2021-09-29': array([], dtype=float64),
#  '2021-10-28': array([], dtype=float64),
#  '2021-11-29': array([], dtype=float64),
#  '2021-12-30': array([], dtype=float64),
#  '2022-01-28': array([], dtype=float64),
#  '2022-02-25': array([], dtype=float64),
#  '2022-03-30': array(['BABA', 'NVDA', 'AMZN'], dtype=object),
#  '2022-04-28': array([], dtype=float64),
#  '2022-05-27': array([], dtype=float64),
#  '2022-06-29': array([], dtype=float64),
#  '2022-07-28': array([], dtype=float64),
#  '2022-08-30': array([], dtype=float64),
#  '2022-09-29': array([], dtype=float64),
#  '2022-10-28': array([], dtype=float64),
#  '2022-11-29': array([], dtype=float64),
#  '2022-12-29': array(['TQQQ', 'BABA', 'AMZN'], dtype=object),
#  '2023-01-30': array(['TQQQ', 'AMZN', 'TSLA'], dtype=object),
#  '2023-02-27': array(['NVDA', 'AMD', 'TQQQ'], dtype=object),
#  '2023-03-30': array([], dtype=float64),
#  '2023-04-27': array([], dtype=float64),
#  '2023-05-30': array(['NVDA', 'AMD', 'TQQQ'], dtype=object),
#  '2023-06-29': array(['NVDA', 'TQQQ', 'AAPL'], dtype=object),
#  '2023-07-28': array(['NVDA', 'GOOGL', 'AAPL'], dtype=object)}

# %%
# Initialize lists to store metrics
annual_returns = []
sharpe_ratios = []
max_drawdowns = []
calmar_ratios = []
sortino_ratios = []

for number in range(18):
    print(f"*******************{number}************************")
    annual_return, sharpe_ratio, max_drawdown_value, calmar_ratio, sortino_ratio = calculate_metrics(returns=retss[number])#[(retss[number].index>'2009-01-01')]

    # Append metrics to their respective lists
    annual_returns.append(annual_return)
    sharpe_ratios.append(sharpe_ratio)
    max_drawdowns.append(max_drawdown_value)
    calmar_ratios.append(calmar_ratio)
    sortino_ratios.append(sortino_ratio)

    # Print results
    print(f"Annual Return: {annual_return * 100:.2f}%")
    print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
    print(f"Max Drawdown: {max_drawdown_value * 100:.2f}%")
    print(f"Calmar Ratio: {calmar_ratio:.2f}")
    print(f"Sortino Ratio: {sortino_ratio:.2f}")

# Calculate averages
avg_annual_return = sum(annual_returns) / len(annual_returns)
avg_sharpe_ratio = sum(sharpe_ratios) / len(sharpe_ratios)
avg_max_drawdown = sum(max_drawdowns) / len(max_drawdowns)
avg_calmar_ratio = sum(calmar_ratios) / len(calmar_ratios)
avg_sortino_ratio = sum(sortino_ratios) / len(sortino_ratios)

# Print averages
print("\n********** Averages **********")
print(f"Average Annual Return: {avg_annual_return * 100:.2f}%")
print(f"Average Sharpe Ratio: {avg_sharpe_ratio:.2f}")
print(f"Average Max Drawdown: {avg_max_drawdown * 100:.2f}%")
print(f"Average Calmar Ratio: {avg_calmar_ratio:.2f}")
print(f"Average Sortino Ratio: {avg_sortino_ratio:.2f}")
# Out:
# *******************0************************
# Annual Return: 19.86%
# Sharpe Ratio: 0.79
# Max Drawdown: 36.02%
# Calmar Ratio: 0.55
# Sortino Ratio: 1.26
# *******************1************************
# Annual Return: 13.05%
# Sharpe Ratio: 0.76
# Max Drawdown: 18.47%
# Calmar Ratio: 0.71
# Sortino Ratio: 0.76
# *******************2************************
# Annual Return: 9.68%
# Sharpe Ratio: 0.62
# Max Drawdown: 24.97%
# Calmar Ratio: 0.39
# Sortino Ratio: 0.34
# *******************3************************
# Annual Return: 9.49%
# Sharpe Ratio: 0.56
# Max Drawdown: 30.34%
# Calmar Ratio: 0.31
# Sortino Ratio: 0.34
# *******************4************************
# Annual Return: 8.62%
# Sharpe Ratio: 0.64
# Max Drawdown: 24.07%
# Calmar Ratio: 0.36
# Sortino Ratio: 0.38
# *******************5************************
# Annual Return: 11.87%
# Sharpe Ratio: 0.75
# Max Drawdown: 25.03%
# Calmar Ratio: 0.47
# Sortino Ratio: 0.45
# *******************6************************
# Annual Return: 15.60%
# Sharpe Ratio: 0.72
# Max Drawdown: 28.31%
# Calmar Ratio: 0.55
# Sortino Ratio: 0.78
# *******************7************************
# Annual Return: 12.96%
# Sharpe Ratio: 0.69
# Max Drawdown: 27.06%
# Calmar Ratio: 0.48
# Sortino Ratio: 0.69
# *******************8************************
# Annual Return: 9.66%
# Sharpe Ratio: 0.55
# Max Drawdown: 37.91%
# Calmar Ratio: 0.25
# Sortino Ratio: 0.47
# *******************9************************
# Annual Return: 11.25%
# Sharpe Ratio: 0.61
# Max Drawdown: 32.47%
# Calmar Ratio: 0.35
# Sortino Ratio: 0.54
# *******************10************************
# Annual Return: 12.57%
# Sharpe Ratio: 0.68
# Max Drawdown: 14.72%
# Calmar Ratio: 0.85
# Sortino Ratio: 1.09
# *******************11************************
# Annual Return: 13.11%
# Sharpe Ratio: 0.67
# Max Drawdown: 17.13%
# Calmar Ratio: 0.76
# Sortino Ratio: 0.84
# *******************12************************
# Annual Return: 12.76%
# Sharpe Ratio: 0.70
# Max Drawdown: 22.20%
# Calmar Ratio: 0.57
# Sortino Ratio: 0.55
# *******************13************************
# Annual Return: 8.73%
# Sharpe Ratio: 0.47
# Max Drawdown: 29.40%
# Calmar Ratio: 0.30
# Sortino Ratio: 0.42
# *******************14************************
# Annual Return: 4.86%
# Sharpe Ratio: 0.36
# Max Drawdown: 28.76%
# Calmar Ratio: 0.17
# Sortino Ratio: 0.22
# *******************15************************
# Annual Return: 5.20%
# Sharpe Ratio: 0.34
# Max Drawdown: 23.87%
# Calmar Ratio: 0.22
# Sortino Ratio: 0.35
# *******************16************************
# Annual Return: 5.63%
# Sharpe Ratio: 0.33
# Max Drawdown: 24.08%
# Calmar Ratio: 0.23
# Sortino Ratio: 0.38
# *******************17************************
# Annual Return: 7.29%
# Sharpe Ratio: 0.42
# Max Drawdown: 30.74%
# Calmar Ratio: 0.24
# Sortino Ratio: 0.41
#
# ********** Averages **********
# Average Annual Return: 10.68%
# Average Sharpe Ratio: 0.59
# Average Max Drawdown: 26.42%
# Average Calmar Ratio: 0.43
# Average Sortino Ratio: 0.57

# %%
# Initialize lists to store metrics
annual_returns = []
sharpe_ratios = []
max_drawdowns = []
calmar_ratios = []
sortino_ratios = []

for number in range(18):
    print(f"*******************{number}************************")
    annual_return, sharpe_ratio, max_drawdown_value, calmar_ratio, sortino_ratio = calculate_metrics(returns=retss[number][(retss[number].index<=DATE_GS_CUTOFF)])#&(retss[number].index>'2009-01-01')

    # Append metrics to their respective lists
    annual_returns.append(annual_return)
    sharpe_ratios.append(sharpe_ratio)
    max_drawdowns.append(max_drawdown_value)
    calmar_ratios.append(calmar_ratio)
    sortino_ratios.append(sortino_ratio)

    # Print results
    print(f"Annual Return: {annual_return * 100:.2f}%")
    print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
    print(f"Max Drawdown: {max_drawdown_value * 100:.2f}%")
    print(f"Calmar Ratio: {calmar_ratio:.2f}")
    print(f"Sortino Ratio: {sortino_ratio:.2f}")

# Calculate averages
avg_annual_return = sum(annual_returns) / len(annual_returns)
avg_sharpe_ratio = sum(sharpe_ratios) / len(sharpe_ratios)
avg_max_drawdown = sum(max_drawdowns) / len(max_drawdowns)
avg_calmar_ratio = sum(calmar_ratios) / len(calmar_ratios)
avg_sortino_ratio = sum(sortino_ratios) / len(sortino_ratios)

# Print averages
print("\n********** Averages **********")
print(f"Average Annual Return: {avg_annual_return * 100:.2f}%")
print(f"Average Sharpe Ratio: {avg_sharpe_ratio:.2f}")
print(f"Average Max Drawdown: {avg_max_drawdown * 100:.2f}%")
print(f"Average Calmar Ratio: {avg_calmar_ratio:.2f}")
print(f"Average Sortino Ratio: {avg_sortino_ratio:.2f}")
# Out:
# *******************0************************
# Annual Return: 19.79%
# Sharpe Ratio: 0.80
# Max Drawdown: 36.02%
# Calmar Ratio: 0.55
# Sortino Ratio: 1.43
# *******************1************************
# Annual Return: 16.46%
# Sharpe Ratio: 0.90
# Max Drawdown: 10.16%
# Calmar Ratio: 1.62
# Sortino Ratio: 1.77
# *******************2************************
# Annual Return: 13.19%
# Sharpe Ratio: 0.84
# Max Drawdown: 24.96%
# Calmar Ratio: 0.53
# Sortino Ratio: 0.45
# *******************3************************
# Annual Return: 11.60%
# Sharpe Ratio: 0.68
# Max Drawdown: 30.34%
# Calmar Ratio: 0.38
# Sortino Ratio: 0.49
# *******************4************************
# Annual Return: 9.42%
# Sharpe Ratio: 0.82
# Max Drawdown: 10.80%
# Calmar Ratio: 0.87
# Sortino Ratio: 0.74
# *******************5************************
# Annual Return: 12.07%
# Sharpe Ratio: 0.91
# Max Drawdown: 11.61%
# Calmar Ratio: 1.04
# Sortino Ratio: 0.87
# *******************6************************
# Annual Return: 17.78%
# Sharpe Ratio: 0.77
# Max Drawdown: 10.28%
# Calmar Ratio: 1.73
# Sortino Ratio: 1.55
# *******************7************************
# Annual Return: 13.64%
# Sharpe Ratio: 0.72
# Max Drawdown: 10.94%
# Calmar Ratio: 1.25
# Sortino Ratio: 1.04
# *******************8************************
# Annual Return: 8.42%
# Sharpe Ratio: 0.49
# Max Drawdown: 37.91%
# Calmar Ratio: 0.22
# Sortino Ratio: 0.39
# *******************9************************
# Annual Return: 9.01%
# Sharpe Ratio: 0.55
# Max Drawdown: 32.47%
# Calmar Ratio: 0.28
# Sortino Ratio: 0.38
# *******************10************************
# Annual Return: 10.85%
# Sharpe Ratio: 0.64
# Max Drawdown: 8.89%
# Calmar Ratio: 1.22
# Sortino Ratio: 0.90
# *******************11************************
# Annual Return: 11.82%
# Sharpe Ratio: 0.63
# Max Drawdown: 5.06%
# Calmar Ratio: 2.34
# Sortino Ratio: 0.96
# *******************12************************
# Annual Return: 12.54%
# Sharpe Ratio: 0.75
# Max Drawdown: 8.15%
# Calmar Ratio: 1.54
# Sortino Ratio: 0.63
# *******************13************************
# Annual Return: 8.18%
# Sharpe Ratio: 0.46
# Max Drawdown: 28.81%
# Calmar Ratio: 0.28
# Sortino Ratio: 0.43
# *******************14************************
# Annual Return: 4.95%
# Sharpe Ratio: 0.37
# Max Drawdown: 28.76%
# Calmar Ratio: 0.17
# Sortino Ratio: 0.20
# *******************15************************
# Annual Return: 5.97%
# Sharpe Ratio: 0.37
# Max Drawdown: 11.02%
# Calmar Ratio: 0.54
# Sortino Ratio: 0.50
# *******************16************************
# Annual Return: 7.63%
# Sharpe Ratio: 0.39
# Max Drawdown: 16.89%
# Calmar Ratio: 0.45
# Sortino Ratio: 0.66
# *******************17************************
# Annual Return: 6.89%
# Sharpe Ratio: 0.41
# Max Drawdown: 30.74%
# Calmar Ratio: 0.22
# Sortino Ratio: 0.40
#
# ********** Averages **********
# Average Annual Return: 11.12%
# Average Sharpe Ratio: 0.64
# Average Max Drawdown: 19.66%
# Average Calmar Ratio: 0.85
# Average Sortino Ratio: 0.77

# %%
for number in range(18):
    plot_returns(returns=retss[number], diffRebal=True)
