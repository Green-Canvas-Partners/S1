# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import numpy as np

import sys
import os
# Current working directory in Jupyter Notebook
project_root = os.getcwd()  # Current working directory
project_root = os.path.join(project_root, '..')  # Move one level up to the root
sys.path.append(project_root)
# from importlib import reload
# import utils.custom
# reload(utils.custom)
from utils.custom import calculate_metrics, plot_returns
from definitions.constants import SINGLE_RUN_STOCK_DICT_PKL, SINGLE_RUN_RETURNS_PKL, DATE_GS_CUTOFF

with open(SINGLE_RUN_RETURNS_PKL, 'rb') as f:
    returns = pickle.load(f)

# %%
with open(SINGLE_RUN_STOCK_DICT_PKL, 'rb') as f:
    dictt = pickle.load(f)

dictt
# Out:
# {'2007-01-31': array(['RIMM', 'PD', 'CMCSA', 'GS', 'X', 'T', 'HPQ', 'CSCO'], dtype=object),
#  '2007-02-28': array(['RIMM', 'PD', 'X', 'GS', 'GM', 'T', 'CMCSA', 'AAPL'], dtype=object),
#  '2007-03-30': array(['X', 'RIMM', 'AAPL', 'T', 'GS', 'MRO', 'CMCSA', 'ORCL'],
#        dtype=object),
#  '2007-04-30': array(['X', 'RIMM', 'AAPL', 'MRK', 'T', 'GS', 'MRO', 'CVX'], dtype=object),
#  '2007-05-31': array(['RIMM', 'AAPL', 'X', 'MRO', 'T', 'MRK', 'GS', 'NVDA'], dtype=object),
#  '2007-06-29': array(['RIMM', 'AAPL', 'NVDA', 'X', 'RIG', 'MRO', 'SLB', 'T'],
#        dtype=object),
#  '2007-07-31': array(['RIMM', 'NVDA', 'AAPL', 'SLB', 'RIG', 'CSCO', 'X', 'AMAT'],
#        dtype=object),
#  '2007-08-31': array(['RIMM', 'AAPL', 'NVDA', 'SLB', 'RIG', 'CSCO', 'IBM', 'X'],
#        dtype=object),
#  '2007-09-28': array(['RIMM', 'AAPL', 'NVDA', 'SLB', 'X', 'RIG', 'EEM', 'OIH'],
#        dtype=object),
#  '2007-10-31': array(['RIMM', 'AAPL', 'GOOG', 'EEM', 'RIG', 'NVDA', 'OXY', 'SLB'],
#        dtype=object),
#  '2007-11-30': array(['RIMM', 'AAPL', 'RIG', 'GOOG', 'OXY', 'EEM', 'MRK', 'KO'],
#        dtype=object),
#  '2007-12-31': array(['RIMM', 'AAPL', 'RIG', 'OXY', 'X', 'GOOG', 'SLB', 'NVDA'],
#        dtype=object),
#  '2008-01-31': array(['BIDU', 'RIMM', 'AMZN', 'DBA', 'GLD', 'EWZ', 'RIG', 'DBC'],
#        dtype=object),
#  '2008-02-29': array(['RIMM', 'BIDU', 'DBA', 'SLV', 'RIG', 'EWZ', 'GLD', 'FCX'],
#        dtype=object),
#  '2008-03-31': array(['RIMM', 'BIDU', 'RIG', 'DBC', 'DBA', 'GSG', 'GLD', 'EWZ'],
#        dtype=object),
#  '2008-04-30': array(['BIDU', 'RIMM', 'EWZ', 'AAPL', 'RIG', 'FCX', 'GSG', 'DBC'],
#        dtype=object),
#  '2008-05-30': array(['RIMM', 'BIDU', 'GSG', 'EWZ', 'DBC', 'AAPL', 'HAL', 'RIG'],
#        dtype=object),
#  '2008-06-30': array([], dtype=float64),
#  '2008-07-31': array([], dtype=float64),
#  '2008-08-29': array([], dtype=float64),
#  '2008-09-30': array([], dtype=float64),
#  '2008-10-31': array([], dtype=float64),
#  '2008-11-28': array([], dtype=float64),
#  '2008-12-31': array([], dtype=float64),
#  '2009-01-30': array([], dtype=float64),
#  '2009-02-27': array([], dtype=float64),
#  '2009-03-31': array([], dtype=float64),
#  '2009-04-30': array([], dtype=float64),
#  '2009-05-29': array([], dtype=float64),
#  '2009-06-30': array([], dtype=float64),
#  '2009-07-31': array(['BIDU', 'AAPL', 'GS', 'AMZN', 'FXI', 'CSCO', 'ORCL', 'HPQ'],
#        dtype=object),
#  '2009-08-31': array(['BIDU', 'GS', 'JPM', 'AAPL', 'FCX', 'SLV', 'GOOG', 'INTC'],
#        dtype=object),
#  '2009-09-30': array(['BIDU', 'AAPL', 'FCX', 'FNM', 'GS', 'EWZ', 'AMZN', 'MS'],
#        dtype=object),
#  '2009-10-30': array(['FCX', 'AMZN', 'BIDU', 'EWZ', 'AAPL', 'GS', 'MS', 'PBR'],
#        dtype=object),
#  '2009-11-30': array(['FCX', 'BIDU', 'AMZN', 'PBR', 'EWZ', 'QLD', 'AAPL', 'MS'],
#        dtype=object),
#  '2009-12-31': array(['FCX', 'BIDU', 'AMZN', 'AAPL', 'QLD', 'GOOG', 'EWZ', 'X'],
#        dtype=object),
#  '2010-01-29': array(['F', 'LVS', 'BIDU', 'AXP', 'AMZN', 'FCX', 'BAC', 'AAPL'],
#        dtype=object),
#  '2010-02-26': array(['F', 'LVS', 'BIDU', 'BAC', 'AXP', 'X', 'QLD', 'CAT'], dtype=object),
#  '2010-03-31': array(['LVS', 'F', 'BIDU', 'X', 'AXP', 'QLD', 'BAC', 'AAPL'], dtype=object),
#  '2010-04-30': array(['LVS', 'BIDU', 'F', 'AAPL', 'QLD', 'AXP', 'CAT', 'BAC'],
#        dtype=object),
#  '2010-05-28': array(['BIDU', 'LVS', 'AAPL', 'F', 'CAT', 'VNQ', 'HD', 'AMZN'],
#        dtype=object),
#  '2010-06-30': array(['LVS', 'BIDU', 'AAPL', 'AIG', 'CAT', 'AXP', 'F', 'ABX'],
#        dtype=object),
#  '2010-07-30': array(['LVS', 'BIDU', 'AIG', 'F', 'CAT', 'AAPL', 'AXP', 'VNQ'],
#        dtype=object),
#  '2010-08-31': array(['BIDU', 'LVS', 'POT', 'ABX', 'GDX', 'CAT', 'F', 'AAPL'],
#        dtype=object),
#  '2010-09-30': array(['BIDU', 'LVS', 'POT', 'AMZN', 'CAT', 'AAPL', 'F', 'SLV'],
#        dtype=object),
#  '2010-10-29': array(['LVS', 'BIDU', 'F', 'SLV', 'QLD', 'POT', 'AAPL', 'AMZN'],
#        dtype=object),
#  '2010-11-30': array(['LVS', 'BIDU', 'F', 'SLV', 'AAPL', 'CAT', 'AMZN', 'FCX'],
#        dtype=object),
#  '2010-12-31': array(['LVS', 'AIG', 'SLV', 'BIDU', 'FCX', 'CAT', 'F', 'AAPL'],
#        dtype=object),
#  '2011-01-31': array(['NFLX', 'LVS', 'BIDU', 'POT', 'TNA', 'CAT', 'SLV', 'HAL'],
#        dtype=object),
#  '2011-02-28': array(['NFLX', 'LVS', 'SLV', 'BIDU', 'TNA', 'CAT', 'POT', 'QCOM'],
#        dtype=object),
#  '2011-03-31': array(['NFLX', 'SLV', 'BIDU', 'TNA', 'CAT', 'HAL', 'LVS', 'POT'],
#        dtype=object),
#  '2011-04-29': array(['SLV', 'BIDU', 'NFLX', 'TNA', 'CAT', 'HAL', 'LVS', 'EMC'],
#        dtype=object),
#  '2011-05-31': array(['NFLX', 'SLV', 'TNA', 'HAL', 'BIDU', 'CAT', 'QCOM', 'POT'],
#        dtype=object),
#  '2011-06-30': array(['NFLX', 'TNA', 'BIDU', 'HAL', 'AMZN', 'SLV', 'POT', 'CAT'],
#        dtype=object),
#  '2011-07-29': array(['NFLX', 'SLV', 'BIDU', 'HAL', 'AMZN', 'LVS', 'AAPL', 'POT'],
#        dtype=object),
#  '2011-08-31': array(['SLV', 'BIDU', 'GLD', 'AMZN', 'NFLX', 'AAPL', 'LVS', 'IBM'],
#        dtype=object),
#  '2011-09-30': array([], dtype=float64),
#  '2011-10-31': array(['SNDK', 'AAPL', 'IBM', 'V', 'GLD', 'INTC', 'AMZN', 'TLT'],
#        dtype=object),
#  '2011-11-30': array(['V', 'TLT', 'IBM', 'MCD', 'GLD', 'NEM', 'INTC', 'HD'], dtype=object),
#  '2011-12-30': array(['V', 'MCD', 'TLT', 'HD', 'PFE', 'AAPL', 'IBM', 'INTC'],
#        dtype=object),
#  '2012-01-31': array(['AAPL', 'MCD', 'TLT', 'INTC', 'PM', 'GLD', 'CAT', 'IBM'],
#        dtype=object),
#  '2012-02-29': array(['AAPL', 'PCLN', 'LVS', 'PM', 'MSFT', 'INTC', 'MCD', 'XRT'],
#        dtype=object),
#  '2012-03-30': array(['AAPL', 'PCLN', 'LVS', 'PM', 'INTC', 'QCOM', 'MSFT', 'CSCO'],
#        dtype=object),
#  '2012-04-30': array(['AAPL', 'PCLN', 'PM', 'INTC', 'MSFT', 'AMZN', 'WFC', 'LVS'],
#        dtype=object),
#  '2012-05-31': array(['AAPL', 'TLT', 'WMT', 'PCLN', 'PM', 'WFC', 'T', 'VZ'], dtype=object),
#  '2012-06-29': array(['AAPL', 'WMT', 'PCLN', 'PM', 'TLT', 'VZ', 'MRK', 'WFC'],
#        dtype=object),
#  '2012-07-31': array(['AAPL', 'WMT', 'T', 'MRK', 'PM', 'PFE', 'VZ', 'PCLN'], dtype=object),
#  '2012-08-31': array(['AAPL', 'FAS', 'WMT', 'SSO', 'WFC', 'TNA', 'T', 'GOOG'],
#        dtype=object),
#  '2012-09-28': array(['FAS', 'AAPL', 'TNA', 'GOOG', 'SSO', 'GE', 'BAC', 'WMT'],
#        dtype=object),
#  '2012-10-31': array(['FAS', 'BAC', 'C', 'WMT', 'MRK', 'AAPL', 'PFE', 'SSO'],
#        dtype=object),
#  '2012-11-30': array(['BAC', 'FAS', 'AMZN', 'YHOO', 'AAPL', 'PCLN', 'C', 'JPM'],
#        dtype=object),
#  '2012-12-31': array(['BAC', 'FAS', 'C', 'NFLX', 'GS', 'YHOO', 'TNA', 'AMZN'],
#        dtype=object),
#  '2013-01-31': array(['NFLX', 'FAS', 'EBAY', 'GILD', 'BAC', 'TNA', 'V', 'MS'],
#        dtype=object),
#  '2013-02-28': array(['NFLX', 'GILD', 'FAS', 'TNA', 'EBAY', 'HD', 'GS', 'BAC'],
#        dtype=object),
#  '2013-03-28': array(['NFLX', 'GILD', 'FAS', 'TNA', 'V', 'BAC', 'CMCSA', 'HD'],
#        dtype=object),
#  '2013-04-30': array(['NFLX', 'GILD', 'FAS', 'TNA', 'BAC', 'C', 'DIS', 'HD'],
#        dtype=object),
#  '2013-05-31': array(['NFLX', 'FAS', 'GILD', 'TNA', 'MS', 'C', 'BAC', 'GS'], dtype=object),
#  '2013-06-28': array(['NFLX', 'FAS', 'GILD', 'TNA', 'MS', 'C', 'F', 'BAC'], dtype=object),
#  '2013-07-31': array(['NFLX', 'FAS', 'TNA', 'GILD', 'MS', 'BAC', 'F', 'C'], dtype=object),
#  '2013-08-30': array(['NFLX', 'GILD', 'TNA', 'FAS', 'PCLN', 'F', 'BAC', 'MS'],
#        dtype=object),
#  '2013-09-30': array(['NFLX', 'TNA', 'GILD', 'FAS', 'BIDU', 'PCLN', 'F', 'SBUX'],
#        dtype=object),
#  '2013-10-31': array(['NFLX', 'TNA', 'GILD', 'FAS', 'BIDU', 'PCLN', 'SBUX', 'AMZN'],
#        dtype=object),
#  '2013-11-29': array(['NFLX', 'TNA', 'FAS', 'GILD', 'BIDU', 'PCLN', 'HPQ', 'MS'],
#        dtype=object),
#  '2013-12-31': array(['NFLX', 'TNA', 'FAS', 'BIDU', 'GILD', 'PCLN', 'MA', 'HPQ'],
#        dtype=object),
#  '2014-01-31': array(['TSLA', 'MU', 'NFLX', 'GILD', 'TNA', 'YHOO', 'HPQ', 'PCLN'],
#        dtype=object),
#  '2014-02-28': array(['TSLA', 'MU', 'NFLX', 'PCLN', 'TNA', 'GILD', 'BIDU', 'YHOO'],
#        dtype=object),
#  '2014-03-31': array(['TSLA', 'MU', 'TNA', 'FAS', 'NFLX', 'HPQ', 'PCLN', 'HAL'],
#        dtype=object),
#  '2014-04-30': array(['TSLA', 'MU', 'HPQ', 'HAL', 'GILD', 'BIDU', 'FAS', 'PCLN'],
#        dtype=object),
#  '2014-05-30': array(['MU', 'TSLA', 'NFLX', 'HAL', 'PCLN', 'BIDU', 'AAPL', 'GILD'],
#        dtype=object),
#  '2014-06-30': array(['MU', 'TSLA', 'NFLX', 'BIDU', 'HAL', 'SLB', 'AAPL', 'TNA'],
#        dtype=object),
#  '2014-07-31': array(['MU', 'BIDU', 'INTC', 'TSLA', 'NFLX', 'GILD', 'HAL', 'AAPL'],
#        dtype=object),
#  '2014-08-29': array(['MU', 'GILD', 'TSLA', 'HPQ', 'INTC', 'NFLX', 'BIDU', 'FAS'],
#        dtype=object),
#  '2014-09-30': array(['MU', 'GILD', 'INTC', 'HPQ', 'BIDU', 'AAPL', 'FAS', 'MSFT'],
#        dtype=object),
#  '2014-10-31': array(['MU', 'GILD', 'BIDU', 'AMGN', 'AAPL', 'FAS', 'YHOO', 'TSLA'],
#        dtype=object),
#  '2014-11-28': array(['MU', 'AAPL', 'YHOO', 'TSLA', 'INTC', 'BIDU', 'AMGN', 'FAS'],
#        dtype=object),
#  '2014-12-31': array(['MU', 'FAS', 'YHOO', 'HPQ', 'AMGN', 'INTC', 'AAPL', 'HD'],
#        dtype=object),
#  '2015-01-30': array(['AGN', 'CELG', 'AAPL', 'DAL', 'HD', 'TLT', 'VNQ', 'GILD'],
#        dtype=object),
#  '2015-02-27': array(['AGN', 'AAPL', 'CELG', 'HD', 'CSCO', 'MDT', 'DIS', 'SSO'],
#        dtype=object),
#  '2015-03-31': array(['AAPL', 'CELG', 'HD', 'DIS', 'FB', 'MDT', 'AMGN', 'TNA'],
#        dtype=object),
#  '2015-04-30': array(['NFLX', 'FXI', 'AMZN', 'AAPL', 'DIS', 'AMGN', 'HD', 'CELG'],
#        dtype=object),
#  '2015-05-29': array(['NFLX', 'AMZN', 'AAPL', 'CELG', 'XIV', 'GILD', 'FXI', 'DIS'],
#        dtype=object),
#  '2015-06-30': array(['AGN', 'NFLX', 'AMZN', 'GILD', 'DIS', 'HD', 'AAPL', 'TSLA'],
#        dtype=object),
#  '2015-07-31': array(['NFLX', 'AGN', 'AMZN', 'CELG', 'XIV', 'V', 'DIS', 'AMGN'],
#        dtype=object),
#  '2015-08-31': array([], dtype=float64),
#  '2015-09-30': array([], dtype=float64),
#  '2015-10-30': array(['AMZN', 'NFLX', 'AGN', 'FB', 'GOOG', 'PCLN', 'V', 'DAL'],
#        dtype=object),
#  '2015-11-30': array(['NFLX', 'AMZN', 'AGN', 'GOOG', 'FB', 'HD', 'EBAY', 'MCD'],
#        dtype=object),
#  '2015-12-31': array([], dtype=float64),
#  '2016-01-29': array([], dtype=float64),
#  '2016-02-29': array([], dtype=float64),
#  '2016-03-31': array(['AMZN', 'FB', 'NFLX', 'GOOG', 'MCD', 'MSFT', 'GE', 'GDX'],
#        dtype=object),
#  '2016-04-29': array(['GDX', 'AMZN', 'FB', 'MCD', 'SLV', 'HD', 'GOOG', 'T'], dtype=object),
#  '2016-05-31': array(['AMZN', 'FB', 'GDX', 'GOOG', 'MCD', 'T', 'JNJ', 'HD'], dtype=object),
#  '2016-06-30': array(['GDX', 'AMZN', 'SLV', 'T', 'JNJ', 'XLU', 'FB', 'HAL'], dtype=object),
#  '2016-07-29': array(['GDX', 'SLV', 'AMZN', 'EWZ', 'FB', 'JNJ', 'T', 'GLD'], dtype=object),
#  '2016-08-31': array(['XIV', 'GDX', 'EWZ', 'AMZN', 'YHOO', 'FB', 'SLV', 'MU'],
#        dtype=object),
#  '2016-09-30': array(['GDX', 'XIV', 'AMZN', 'EWZ', 'YHOO', 'MU', 'QCOM', 'CAT'],
#        dtype=object),
#  '2016-10-31': array(['EWZ', 'GDX', 'NFLX', 'XIV', 'QCOM', 'AMZN', 'FB', 'MU'],
#        dtype=object),
#  '2016-11-30': array(['XIV', 'MU', 'BAC', 'HAL', 'CAT', 'GS', 'EWZ', 'QCOM'],
#        dtype=object),
#  '2016-12-30': array(['XIV', 'MU', 'BAC', 'GS', 'HAL', 'JPM', 'EWZ', 'CAT'], dtype=object),
#  '2017-01-31': array(['NVDA', 'XIV', 'BAC', 'EWZ', 'NFLX', 'GS', 'JPM', 'GDXJ'],
#        dtype=object),
#  '2017-02-28': array(['XIV', 'NVDA', 'BAC', 'GS', 'JPM', 'BA', 'EWZ', 'NFLX'],
#        dtype=object),
#  '2017-03-31': array(['XIV', 'NVDA', 'BAC', 'NFLX', 'JPM', 'BA', 'GS', 'AAPL'],
#        dtype=object),
#  '2017-04-28': array(['XIV', 'NVDA', 'NFLX', 'BAC', 'TSLA', 'AAPL', 'BABA', 'BA'],
#        dtype=object),
#  '2017-05-31': array(['NVDA', 'XIV', 'TSLA', 'NFLX', 'BABA', 'AAPL', 'BA', 'PCLN'],
#        dtype=object),
#  '2017-06-30': array(['XIV', 'NVDA', 'TSLA', 'BABA', 'BAC', 'C', 'BA', 'NFLX'],
#        dtype=object),
#  '2017-07-31': array(['NVDA', 'XIV', 'BA', 'BABA', 'NFLX', 'BIDU', 'C', 'PCLN'],
#        dtype=object),
#  '2017-08-31': array(['NVDA', 'XIV', 'BABA', 'BA', 'TSLA', 'NFLX', 'AAPL', 'FB'],
#        dtype=object),
#  '2017-09-29': array(['NVDA', 'XIV', 'BA', 'BABA', 'NFLX', 'TSLA', 'BIDU', 'C'],
#        dtype=object),
#  '2017-10-31': array(['NVDA', 'XIV', 'BABA', 'BA', 'NFLX', 'BAC', 'TSLA', 'BIDU'],
#        dtype=object),
#  '2017-11-30': array(['XIV', 'NVDA', 'BABA', 'BA', 'AMZN', 'AAPL', 'WMT', 'NFLX'],
#        dtype=object),
#  '2017-12-29': array(['XIV', 'BA', 'VRX', 'NVDA', 'BABA', 'AMZN', 'WMT', 'HD'],
#        dtype=object),
#  '2018-01-31': array(['BA', 'NVDA', 'NFLX', 'BABA', 'XIV', 'AMZN', 'MU', 'JD'],
#        dtype=object),
#  '2018-02-28': array(['NFLX', 'NVDA', 'BA', 'MU', 'AMZN', 'BABA', 'MSFT', 'JD'],
#        dtype=object),
#  '2018-03-29': array(['NFLX', 'NVDA', 'MU', 'BA', 'UCO', 'AMZN', 'INTC', 'BABA'],
#        dtype=object),
#  '2018-04-30': array(['NFLX', 'UCO', 'NVDA', 'AMZN', 'BA', 'MU', 'INTC', 'CSCO'],
#        dtype=object),
#  '2018-05-31': array(['NFLX', 'MU', 'UCO', 'BA', 'AMZN', 'NVDA', 'INTC', 'BABA'],
#        dtype=object),
#  '2018-06-29': array(['NFLX', 'UCO', 'AMZN', 'MU', 'BA', 'NKE', 'NVDA', 'XOP'],
#        dtype=object),
#  '2018-07-31': array(['AMZN', 'NFLX', 'UCO', 'AMD', 'MU', 'MSFT', 'BA', 'NVDA'],
#        dtype=object),
#  '2018-08-31': array(['AMD', 'AMZN', 'NFLX', 'UCO', 'NVDA', 'NKE', 'AAPL', 'MSFT'],
#        dtype=object),
#  '2018-09-28': array(['AMD', 'AMZN', 'UCO', 'NFLX', 'NKE', 'NVDA', 'AAPL', 'MSFT'],
#        dtype=object),
#  '2018-10-31': array(['AMD', 'MRK', 'AAPL', 'PFE', 'BA', 'NKE', 'MSFT', 'CSCO'],
#        dtype=object),
#  '2018-11-30': array(['AMD', 'MRK', 'PFE', 'MSFT', 'SBUX', 'UNH', 'AMZN', 'VZ'],
#        dtype=object),
#  '2018-12-31': array([], dtype=float64),
#  '2019-01-31': array(['AMD', 'SQ', 'CRM', 'MRK', 'PG', 'MA', 'NFLX', 'TWTR'],
#        dtype=object),
#  '2019-02-28': array(['AMD', 'SQ', 'MRK', 'CRM', 'BA', 'PG', 'MA', 'PYPL'], dtype=object),
#  '2019-03-29': array(['AMD', 'MRK', 'PYPL', 'AVGO', 'PG', 'SQ', 'MA', 'CSCO'],
#        dtype=object),
#  '2019-04-30': array(['AMD', 'QCOM', 'PYPL', 'AVGO', 'MA', 'PG', 'TQQQ', 'MSFT'],
#        dtype=object),
#  '2019-05-31': array(['AMD', 'PYPL', 'MA', 'PG', 'DIS', 'CMCSA', 'MSFT', 'MRK'],
#        dtype=object),
#  '2019-06-28': array(['AMD', 'PYPL', 'QCOM', 'MA', 'MSFT', 'PG', 'DIS', 'V'],
#        dtype=object),
#  '2019-07-31': array(['AMD', 'PG', 'TWTR', 'MA', 'GDX', 'V', 'MSFT', 'DIS'], dtype=object),
#  '2019-08-30': array(['GDX', 'PG', 'MA', 'AMD', 'SLV', 'TWTR', 'MCD', 'GLD'],
#        dtype=object),
#  '2019-09-30': array(['PG', 'TWTR', 'GDX', 'WMT', 'CMCSA', 'MSFT', 'MCD', 'MA'],
#        dtype=object),
#  '2019-10-31': array(['AMD', 'GDX', 'TQQQ', 'SMH', 'PG', 'HD', 'MA', 'AAPL'],
#        dtype=object),
#  '2019-11-29': array(['AMD', 'TQQQ', 'AAPL', 'NVDA', 'QCOM', 'MA', 'GE', 'SMH'],
#        dtype=object),
#  '2019-12-31': array(['AMD', 'TQQQ', 'AAPL', 'TSLA', 'NVDA', 'MU', 'SMH', 'BABA'],
#        dtype=object),
#  '2020-01-31': array(['TSLA', 'SHOP', 'TQQQ', 'AMD', 'ROKU', 'AAPL', 'NVDA', 'MSFT'],
#        dtype=object),
#  '2020-02-28': array(['TSLA', 'SHOP', 'NVDA', 'AMD', 'AAPL', 'MSFT', 'TQQQ', 'ADBE'],
#        dtype=object),
#  '2020-03-31': array([], dtype=float64),
#  '2020-04-30': array(['TSLA', 'SHOP', 'AMD', 'NVDA', 'GDX', 'AMZN', 'ROKU', 'MSFT'],
#        dtype=object),
#  '2020-05-29': array(['TSLA', 'SHOP', 'NVDA', 'AMD', 'AAPL', 'PYPL', 'GDX', 'TQQQ'],
#        dtype=object),
#  '2020-06-30': array(['TSLA', 'SHOP', 'NVDA', 'PYPL', 'AAPL', 'SQ', 'TQQQ', 'AMZN'],
#        dtype=object),
#  '2020-07-31': array(['TSLA', 'SHOP', 'AMD', 'NVDA', 'SQ', 'TQQQ', 'PYPL', 'AAPL'],
#        dtype=object),
#  '2020-08-31': array(['TSLA', 'NVDA', 'TQQQ', 'SQ', 'AMD', 'SHOP', 'AAPL', 'PYPL'],
#        dtype=object),
#  '2020-09-30': array(['TSLA', 'SQ', 'NVDA', 'SHOP', 'AMD', 'TQQQ', 'AAPL', 'PYPL'],
#        dtype=object),
#  '2020-10-30': array(['TSLA', 'SQ', 'SHOP', 'NVDA', 'AMD', 'BABA', 'PYPL', 'ROKU'],
#        dtype=object),
#  '2020-11-30': array(['TSLA', 'SQ', 'ROKU', 'SHOP', 'AMD', 'NVDA', 'TQQQ', 'QCOM'],
#        dtype=object),
#  '2020-12-31': array(['TSLA', 'SQ', 'ROKU', 'SHOP', 'TQQQ', 'PYPL', 'NVDA', 'QCOM'],
#        dtype=object),
#  '2021-01-29': array(['NIO', 'MRNA', 'TSLA', 'ROKU', 'SQ', 'TQQQ', 'JD', 'SHOP'],
#        dtype=object),
#  '2021-02-26': array(['NIO', 'MRNA', 'TSLA', 'ROKU', 'SQ', 'SHOP', 'TQQQ', 'PYPL'],
#        dtype=object),
#  '2021-03-31': array(['NIO', 'TSLA', 'SQ', 'MRNA', 'ROKU', 'TQQQ', 'CCL', 'AAL'],
#        dtype=object),
#  '2021-04-30': array(['NIO', 'UCO', 'MRNA', 'TSLA', 'SQ', 'TQQQ', 'ROKU', 'CCL'],
#        dtype=object),
#  '2021-05-28': array(['NIO', 'MRNA', 'UCO', 'ROKU', 'TSLA', 'AAL', 'TQQQ', 'SQ'],
#        dtype=object),
#  '2021-06-30': array(['NIO', 'MRNA', 'ROKU', 'UCO', 'TQQQ', 'TSLA', 'NVDA', 'WFC'],
#        dtype=object),
#  '2021-07-30': array(['MRNA', 'UCO', 'NIO', 'ROKU', 'TQQQ', 'TSLA', 'NVDA', 'WFC'],
#        dtype=object),
#  '2021-08-31': array(['MRNA', 'UCO', 'TQQQ', 'NVDA', 'GOOGL', 'GOOG', 'WFC', 'SQ'],
#        dtype=object),
#  '2021-09-30': array(['MRNA', 'UCO', 'WFC', 'GOOGL', 'TQQQ', 'GOOG', 'TSLA', 'NVDA'],
#        dtype=object),
#  '2021-10-29': array(['MRNA', 'UCO', 'TSLA', 'TQQQ', 'NVDA', 'WFC', 'BAC', 'GOOGL'],
#        dtype=object),
#  '2021-11-30': array(['NVDA', 'MRNA', 'TSLA', 'AMD', 'TQQQ', 'COST', 'UCO', 'PFE'],
#        dtype=object),
#  '2021-12-31': array(['NVDA', 'UCO', 'TQQQ', 'PFE', 'AMD', 'TSLA', 'COST', 'MRNA'],
#        dtype=object),
#  '2022-01-31': array(['UCO', 'F', 'XOM', 'XLE', 'NVDA', 'WFC', 'CVX', 'PFE'],
#        dtype=object),
#  '2022-02-28': array(['UCO', 'NVDA', 'XLE', 'CVX', 'GSG', 'XOM', 'DBC', 'AMD'],
#        dtype=object),
#  '2022-03-31': array(['UCO', 'CVX', 'NVDA', 'GSG', 'XLE', 'TSLA', 'DBC', 'XOM'],
#        dtype=object),
#  '2022-04-29': array([], dtype=float64),
#  '2022-05-31': array([], dtype=float64),
#  '2022-06-30': array([], dtype=float64),
#  '2022-07-29': array([], dtype=float64),
#  '2022-08-31': array([], dtype=float64),
#  '2022-09-30': array([], dtype=float64),
#  '2022-10-31': array([], dtype=float64),
#  '2022-11-30': array([], dtype=float64),
#  '2022-12-30': array([], dtype=float64),
#  '2023-01-31': array(['XOM', 'OXY', 'BA', 'XLE', 'CVX', 'NFLX', 'MRNA', 'SLV'],
#        dtype=object),
#  '2023-02-28': array([], dtype=float64),
#  '2023-03-31': array(['NVDA', 'BA', 'XOM', 'NFLX', 'AVGO', 'CRM', 'AMD', 'SMH'],
#        dtype=object),
#  '2023-04-28': array(['NVDA', 'NFLX', 'BA', 'XOM', 'SHOP', 'CRM', 'MSFT', 'SLV'],
#        dtype=object),
#  '2023-05-31': array(['NVDA', 'NFLX', 'SHOP', 'AVGO', 'CRM', 'AMD', 'BA', 'TQQQ'],
#        dtype=object),
#  '2023-06-30': array(['NVDA', 'SOXL', 'NFLX', 'SHOP', 'TQQQ', 'AVGO', 'AMD', 'SMH'],
#        dtype=object),
#  '2023-07-31': array(['NVDA', 'SOXL', 'SHOP', 'TQQQ', 'NFLX', 'AVGO', 'ADBE', 'BA'],
#        dtype=object),
#  '2023-08-31': array(['NVDA', 'SHOP', 'AVGO', 'SOXL', 'TQQQ', 'NFLX', 'ADBE', 'SMH'],
#        dtype=object),
#  '2023-09-29': array(['NVDA', 'ADBE', 'AVGO', 'SOXL', 'TQQQ', 'SHOP', 'AMD', 'UCO'],
#        dtype=object),
#  '2023-10-31': array(['NVDA', 'ADBE', 'AVGO', 'MSFT', 'AMD', 'TQQQ', 'NFLX', 'AMZN'],
#        dtype=object),
#  '2023-11-30': array(['NVDA', 'TQQQ', 'SHOP', 'ADBE', 'INTC', 'CRM', 'SOXL', 'AVGO'],
#        dtype=object),
#  '2023-12-29': array(['SOXL', 'TQQQ', 'NVDA', 'AMD', 'SHOP', 'INTC', 'AVGO', 'CRM'],
#        dtype=object),
#  '2024-01-31': array(['NVDA', 'SOXL', 'AMD', 'COIN', 'TQQQ', 'UBER', 'PANW', 'AVGO'],
#        dtype=object),
#  '2024-02-29': array(['COIN', 'NVDA', 'SOXL', 'PLTR', 'AMD', 'TQQQ', 'UBER', 'LLY'],
#        dtype=object),
#  '2024-03-28': array(['COIN', 'NVDA', 'SOXL', 'PLTR', 'UBER', 'TQQQ', 'MU', 'LLY'],
#        dtype=object),
#  '2024-04-30': array(['COIN', 'NVDA', 'SOXL', 'PLTR', 'MU', 'AVGO', 'LLY', 'UBER'],
#        dtype=object),
#  '2024-05-31': array(['COIN', 'NVDA', 'SOXL', 'MU', 'PDD', 'QCOM', 'LLY', 'SMH'],
#        dtype=object),
#  '2024-06-28': array(['NVDA', 'COIN', 'SOXL', 'MU', 'TQQQ', 'AVGO', 'TSM', 'LLY'],
#        dtype=object),
#  '2024-07-31': array(['NVDA', 'COIN', 'AVGO', 'TSM', 'SPXL', 'SOXL', 'TQQQ', 'LLY'],
#        dtype=object),
#  '2024-08-30': array(['NVDA', 'PLTR', 'TSM', 'LLY', 'SPXL', 'AVGO', 'COIN', 'NFLX'],
#        dtype=object),
#  '2024-09-30': array(['PLTR', 'NVDA', 'SPXL', 'AVGO', 'TQQQ', 'TSM', 'ORCL', 'NFLX'],
#        dtype=object),
#  '2024-10-31': array(['PLTR', 'NVDA', 'TSM', 'SPXL', 'AVGO', 'NFLX', 'TQQQ', 'ORCL'],
#        dtype=object),
#  '2024-11-29': array(['PLTR', 'NVDA', 'COIN', 'SPXL', 'NFLX', 'TSLA', 'WMT', 'WFC'],
#        dtype=object),
#  '2024-12-31': array(['PLTR', 'AVGO', 'TSLA', 'NVDA', 'NFLX', 'TSM', 'WMT', 'TQQQ'],
#        dtype=object),
#  '2025-01-31': array(['PLTR', 'MSTR', 'TSLA', 'ARKB', 'COIN', 'AVGO', 'NFLX', 'WMT'],
#        dtype=object),
#  '2025-02-28': array(['PLTR', 'BABA', 'MSTR', 'NFLX', 'WMT', 'GS', 'FXI', 'WFC'],
#        dtype=object)}

# %%
# dictt
filtered_keys = {k: v for k, v in dictt.items() if k > DATE_GS_CUTOFF}
filtered_keys
# Out:
# {'2018-01-31': array(['BA', 'NVDA', 'NFLX', 'BABA', 'XIV', 'AMZN', 'MU', 'JD'],
#        dtype=object),
#  '2018-02-28': array(['NFLX', 'NVDA', 'BA', 'MU', 'AMZN', 'BABA', 'MSFT', 'JD'],
#        dtype=object),
#  '2018-03-29': array(['NFLX', 'NVDA', 'MU', 'BA', 'UCO', 'AMZN', 'INTC', 'BABA'],
#        dtype=object),
#  '2018-04-30': array(['NFLX', 'UCO', 'NVDA', 'AMZN', 'BA', 'MU', 'INTC', 'CSCO'],
#        dtype=object),
#  '2018-05-31': array(['NFLX', 'MU', 'UCO', 'BA', 'AMZN', 'NVDA', 'INTC', 'BABA'],
#        dtype=object),
#  '2018-06-29': array(['NFLX', 'UCO', 'AMZN', 'MU', 'BA', 'NKE', 'NVDA', 'XOP'],
#        dtype=object),
#  '2018-07-31': array(['AMZN', 'NFLX', 'UCO', 'AMD', 'MU', 'MSFT', 'BA', 'NVDA'],
#        dtype=object),
#  '2018-08-31': array(['AMD', 'AMZN', 'NFLX', 'UCO', 'NVDA', 'NKE', 'AAPL', 'MSFT'],
#        dtype=object),
#  '2018-09-28': array(['AMD', 'AMZN', 'UCO', 'NFLX', 'NKE', 'NVDA', 'AAPL', 'MSFT'],
#        dtype=object),
#  '2018-10-31': array(['AMD', 'MRK', 'AAPL', 'PFE', 'BA', 'NKE', 'MSFT', 'CSCO'],
#        dtype=object),
#  '2018-11-30': array(['AMD', 'MRK', 'PFE', 'MSFT', 'SBUX', 'UNH', 'AMZN', 'VZ'],
#        dtype=object),
#  '2018-12-31': array([], dtype=float64),
#  '2019-01-31': array(['AMD', 'SQ', 'CRM', 'MRK', 'PG', 'MA', 'NFLX', 'TWTR'],
#        dtype=object),
#  '2019-02-28': array(['AMD', 'SQ', 'MRK', 'CRM', 'BA', 'PG', 'MA', 'PYPL'], dtype=object),
#  '2019-03-29': array(['AMD', 'MRK', 'PYPL', 'AVGO', 'PG', 'SQ', 'MA', 'CSCO'],
#        dtype=object),
#  '2019-04-30': array(['AMD', 'QCOM', 'PYPL', 'AVGO', 'MA', 'PG', 'TQQQ', 'MSFT'],
#        dtype=object),
#  '2019-05-31': array(['AMD', 'PYPL', 'MA', 'PG', 'DIS', 'CMCSA', 'MSFT', 'MRK'],
#        dtype=object),
#  '2019-06-28': array(['AMD', 'PYPL', 'QCOM', 'MA', 'MSFT', 'PG', 'DIS', 'V'],
#        dtype=object),
#  '2019-07-31': array(['AMD', 'PG', 'TWTR', 'MA', 'GDX', 'V', 'MSFT', 'DIS'], dtype=object),
#  '2019-08-30': array(['GDX', 'PG', 'MA', 'AMD', 'SLV', 'TWTR', 'MCD', 'GLD'],
#        dtype=object),
#  '2019-09-30': array(['PG', 'TWTR', 'GDX', 'WMT', 'CMCSA', 'MSFT', 'MCD', 'MA'],
#        dtype=object),
#  '2019-10-31': array(['AMD', 'GDX', 'TQQQ', 'SMH', 'PG', 'HD', 'MA', 'AAPL'],
#        dtype=object),
#  '2019-11-29': array(['AMD', 'TQQQ', 'AAPL', 'NVDA', 'QCOM', 'MA', 'GE', 'SMH'],
#        dtype=object),
#  '2019-12-31': array(['AMD', 'TQQQ', 'AAPL', 'TSLA', 'NVDA', 'MU', 'SMH', 'BABA'],
#        dtype=object),
#  '2020-01-31': array(['TSLA', 'SHOP', 'TQQQ', 'AMD', 'ROKU', 'AAPL', 'NVDA', 'MSFT'],
#        dtype=object),
#  '2020-02-28': array(['TSLA', 'SHOP', 'NVDA', 'AMD', 'AAPL', 'MSFT', 'TQQQ', 'ADBE'],
#        dtype=object),
#  '2020-03-31': array([], dtype=float64),
#  '2020-04-30': array(['TSLA', 'SHOP', 'AMD', 'NVDA', 'GDX', 'AMZN', 'ROKU', 'MSFT'],
#        dtype=object),
#  '2020-05-29': array(['TSLA', 'SHOP', 'NVDA', 'AMD', 'AAPL', 'PYPL', 'GDX', 'TQQQ'],
#        dtype=object),
#  '2020-06-30': array(['TSLA', 'SHOP', 'NVDA', 'PYPL', 'AAPL', 'SQ', 'TQQQ', 'AMZN'],
#        dtype=object),
#  '2020-07-31': array(['TSLA', 'SHOP', 'AMD', 'NVDA', 'SQ', 'TQQQ', 'PYPL', 'AAPL'],
#        dtype=object),
#  '2020-08-31': array(['TSLA', 'NVDA', 'TQQQ', 'SQ', 'AMD', 'SHOP', 'AAPL', 'PYPL'],
#        dtype=object),
#  '2020-09-30': array(['TSLA', 'SQ', 'NVDA', 'SHOP', 'AMD', 'TQQQ', 'AAPL', 'PYPL'],
#        dtype=object),
#  '2020-10-30': array(['TSLA', 'SQ', 'SHOP', 'NVDA', 'AMD', 'BABA', 'PYPL', 'ROKU'],
#        dtype=object),
#  '2020-11-30': array(['TSLA', 'SQ', 'ROKU', 'SHOP', 'AMD', 'NVDA', 'TQQQ', 'QCOM'],
#        dtype=object),
#  '2020-12-31': array(['TSLA', 'SQ', 'ROKU', 'SHOP', 'TQQQ', 'PYPL', 'NVDA', 'QCOM'],
#        dtype=object),
#  '2021-01-29': array(['NIO', 'MRNA', 'TSLA', 'ROKU', 'SQ', 'TQQQ', 'JD', 'SHOP'],
#        dtype=object),
#  '2021-02-26': array(['NIO', 'MRNA', 'TSLA', 'ROKU', 'SQ', 'SHOP', 'TQQQ', 'PYPL'],
#        dtype=object),
#  '2021-03-31': array(['NIO', 'TSLA', 'SQ', 'MRNA', 'ROKU', 'TQQQ', 'CCL', 'AAL'],
#        dtype=object),
#  '2021-04-30': array(['NIO', 'UCO', 'MRNA', 'TSLA', 'SQ', 'TQQQ', 'ROKU', 'CCL'],
#        dtype=object),
#  '2021-05-28': array(['NIO', 'MRNA', 'UCO', 'ROKU', 'TSLA', 'AAL', 'TQQQ', 'SQ'],
#        dtype=object),
#  '2021-06-30': array(['NIO', 'MRNA', 'ROKU', 'UCO', 'TQQQ', 'TSLA', 'NVDA', 'WFC'],
#        dtype=object),
#  '2021-07-30': array(['MRNA', 'UCO', 'NIO', 'ROKU', 'TQQQ', 'TSLA', 'NVDA', 'WFC'],
#        dtype=object),
#  '2021-08-31': array(['MRNA', 'UCO', 'TQQQ', 'NVDA', 'GOOGL', 'GOOG', 'WFC', 'SQ'],
#        dtype=object),
#  '2021-09-30': array(['MRNA', 'UCO', 'WFC', 'GOOGL', 'TQQQ', 'GOOG', 'TSLA', 'NVDA'],
#        dtype=object),
#  '2021-10-29': array(['MRNA', 'UCO', 'TSLA', 'TQQQ', 'NVDA', 'WFC', 'BAC', 'GOOGL'],
#        dtype=object),
#  '2021-11-30': array(['NVDA', 'MRNA', 'TSLA', 'AMD', 'TQQQ', 'COST', 'UCO', 'PFE'],
#        dtype=object),
#  '2021-12-31': array(['NVDA', 'UCO', 'TQQQ', 'PFE', 'AMD', 'TSLA', 'COST', 'MRNA'],
#        dtype=object),
#  '2022-01-31': array(['UCO', 'F', 'XOM', 'XLE', 'NVDA', 'WFC', 'CVX', 'PFE'],
#        dtype=object),
#  '2022-02-28': array(['UCO', 'NVDA', 'XLE', 'CVX', 'GSG', 'XOM', 'DBC', 'AMD'],
#        dtype=object),
#  '2022-03-31': array(['UCO', 'CVX', 'NVDA', 'GSG', 'XLE', 'TSLA', 'DBC', 'XOM'],
#        dtype=object),
#  '2022-04-29': array([], dtype=float64),
#  '2022-05-31': array([], dtype=float64),
#  '2022-06-30': array([], dtype=float64),
#  '2022-07-29': array([], dtype=float64),
#  '2022-08-31': array([], dtype=float64),
#  '2022-09-30': array([], dtype=float64),
#  '2022-10-31': array([], dtype=float64),
#  '2022-11-30': array([], dtype=float64),
#  '2022-12-30': array([], dtype=float64),
#  '2023-01-31': array(['XOM', 'OXY', 'BA', 'XLE', 'CVX', 'NFLX', 'MRNA', 'SLV'],
#        dtype=object),
#  '2023-02-28': array([], dtype=float64),
#  '2023-03-31': array(['NVDA', 'BA', 'XOM', 'NFLX', 'AVGO', 'CRM', 'AMD', 'SMH'],
#        dtype=object),
#  '2023-04-28': array(['NVDA', 'NFLX', 'BA', 'XOM', 'SHOP', 'CRM', 'MSFT', 'SLV'],
#        dtype=object),
#  '2023-05-31': array(['NVDA', 'NFLX', 'SHOP', 'AVGO', 'CRM', 'AMD', 'BA', 'TQQQ'],
#        dtype=object),
#  '2023-06-30': array(['NVDA', 'SOXL', 'NFLX', 'SHOP', 'TQQQ', 'AVGO', 'AMD', 'SMH'],
#        dtype=object),
#  '2023-07-31': array(['NVDA', 'SOXL', 'SHOP', 'TQQQ', 'NFLX', 'AVGO', 'ADBE', 'BA'],
#        dtype=object),
#  '2023-08-31': array(['NVDA', 'SHOP', 'AVGO', 'SOXL', 'TQQQ', 'NFLX', 'ADBE', 'SMH'],
#        dtype=object),
#  '2023-09-29': array(['NVDA', 'ADBE', 'AVGO', 'SOXL', 'TQQQ', 'SHOP', 'AMD', 'UCO'],
#        dtype=object),
#  '2023-10-31': array(['NVDA', 'ADBE', 'AVGO', 'MSFT', 'AMD', 'TQQQ', 'NFLX', 'AMZN'],
#        dtype=object),
#  '2023-11-30': array(['NVDA', 'TQQQ', 'SHOP', 'ADBE', 'INTC', 'CRM', 'SOXL', 'AVGO'],
#        dtype=object),
#  '2023-12-29': array(['SOXL', 'TQQQ', 'NVDA', 'AMD', 'SHOP', 'INTC', 'AVGO', 'CRM'],
#        dtype=object),
#  '2024-01-31': array(['NVDA', 'SOXL', 'AMD', 'COIN', 'TQQQ', 'UBER', 'PANW', 'AVGO'],
#        dtype=object),
#  '2024-02-29': array(['COIN', 'NVDA', 'SOXL', 'PLTR', 'AMD', 'TQQQ', 'UBER', 'LLY'],
#        dtype=object),
#  '2024-03-28': array(['COIN', 'NVDA', 'SOXL', 'PLTR', 'UBER', 'TQQQ', 'MU', 'LLY'],
#        dtype=object),
#  '2024-04-30': array(['COIN', 'NVDA', 'SOXL', 'PLTR', 'MU', 'AVGO', 'LLY', 'UBER'],
#        dtype=object),
#  '2024-05-31': array(['COIN', 'NVDA', 'SOXL', 'MU', 'PDD', 'QCOM', 'LLY', 'SMH'],
#        dtype=object),
#  '2024-06-28': array(['NVDA', 'COIN', 'SOXL', 'MU', 'TQQQ', 'AVGO', 'TSM', 'LLY'],
#        dtype=object),
#  '2024-07-31': array(['NVDA', 'COIN', 'AVGO', 'TSM', 'SPXL', 'SOXL', 'TQQQ', 'LLY'],
#        dtype=object),
#  '2024-08-30': array(['NVDA', 'PLTR', 'TSM', 'LLY', 'SPXL', 'AVGO', 'COIN', 'NFLX'],
#        dtype=object),
#  '2024-09-30': array(['PLTR', 'NVDA', 'SPXL', 'AVGO', 'TQQQ', 'TSM', 'ORCL', 'NFLX'],
#        dtype=object),
#  '2024-10-31': array(['PLTR', 'NVDA', 'TSM', 'SPXL', 'AVGO', 'NFLX', 'TQQQ', 'ORCL'],
#        dtype=object),
#  '2024-11-29': array(['PLTR', 'NVDA', 'COIN', 'SPXL', 'NFLX', 'TSLA', 'WMT', 'WFC'],
#        dtype=object),
#  '2024-12-31': array(['PLTR', 'AVGO', 'TSLA', 'NVDA', 'NFLX', 'TSM', 'WMT', 'TQQQ'],
#        dtype=object),
#  '2025-01-31': array(['PLTR', 'MSTR', 'TSLA', 'ARKB', 'COIN', 'AVGO', 'NFLX', 'WMT'],
#        dtype=object),
#  '2025-02-28': array(['PLTR', 'BABA', 'MSTR', 'NFLX', 'WMT', 'GS', 'FXI', 'WFC'],
#        dtype=object)}

# %%
xiv_count = 0

# Iterate through the dictionary values
for date, tickers in dictt.items():
    if 'XIV' in tickers:
        xiv_count += 1

print(f"The stock ticker 'XIV' appears {xiv_count} times in the dictionary.")
# Out:
# The stock ticker 'XIV' appears 20 times in the dictionary.
# /tmp/ipykernel_960730/4187050076.py:5: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'XIV' in tickers:

# %%
returns[returns.index > '2018-01-01'].head(10)
# Out:
# 2018-01-31     3.097453
# 2018-02-28    -3.391839
# 2018-03-29     1.385013
# 2018-04-30     8.287035
# 2018-05-31     1.422492
# 2018-06-29    -5.150818
# 2018-07-31    12.749346
# 2018-08-31     8.192575
# 2018-09-28   -24.923394
# 2018-10-31     7.742763
# dtype: float64

# %%
annual_return, sharpe_ratio, max_drawdown_value, calmar_ratio, sortino_ratio = calculate_metrics(returns=returns)#[(returns.index>'2009-01-01')]
# Print results
print(f"Annual Return: {annual_return * 100:.2f}%")
print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
print(f"Max Drawdown: {max_drawdown_value * 100:.2f}%")
print(f"Calmar Ratio: {calmar_ratio:.2f}")
print(f"Sortino Ratio: {sortino_ratio:.2f}")
# Out:
# Annual Return: 26.60%
# Sharpe Ratio: 0.95
# Max Drawdown: 32.36%
# Calmar Ratio: 0.82
# Sortino Ratio: 1.56

# %%
annual_return, sharpe_ratio, max_drawdown_value, calmar_ratio, sortino_ratio = calculate_metrics(returns=returns[(returns.index<=DATE_GS_CUTOFF)])#&(returns.index>'2009-01-01')

# Print results
print(f"Annual Return: {annual_return * 100:.2f}%")
print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
print(f"Max Drawdown: {max_drawdown_value * 100:.2f}%")
print(f"Calmar Ratio: {calmar_ratio:.2f}")
print(f"Sortino Ratio: {sortino_ratio:.2f}")
# Out:
# Annual Return: 24.49%
# Sharpe Ratio: 1.04
# Max Drawdown: 31.69%
# Calmar Ratio: 0.77
# Sortino Ratio: 1.49

# %%
plot_returns(returns=returns)
